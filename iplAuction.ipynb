# %%
import numpy as np
import pandas as pd
import os

data = pd.read_csv("C:/Users/Vivek chadhuvula/Documents/iplAuction/iplauction2023.csv")
data
# Out:
#                 name player style   nationality  base price (in lacs)
# 0       Harshit Rana       Bowler         India                   NaN  \
# 1          Ekant Sen       Batter         India                  20.0
# 2      Wayne Parnell   Allrounder  South Africa                  75.0
# 3    Shakib Al Hasan   Allrounder    Bangladesh                 150.0
# 4           Joe Root       Batter       England                 100.0
# ..               ...          ...           ...                   ...
# 304         MS Dhoni    WK-Batter         India                   NaN
# 305        Moeen Ali   Allrounder       England                   NaN
# 306  Ruturaj Gaikwad       Batter         India                   NaN
# 307     Rishabh Pant    WK-Batter         India                   NaN
# 308       Axar Patel   Allrounder         India                   NaN
#
#      final price (in lacs) franchise    status
# 0                     20.0       KKR  RETAINED
# ...

# %%
data.head(10)
# Out:
#                    name player style   nationality  base price (in lacs)
# 0          Harshit Rana       Bowler         India                   NaN  \
# 1             Ekant Sen       Batter         India                  20.0
# 2         Wayne Parnell   Allrounder  South Africa                  75.0
# 3       Shakib Al Hasan   Allrounder    Bangladesh                 150.0
# 4              Joe Root       Batter       England                 100.0
# 5          Abdul Basith   Allrounder         India                  20.0
# 6       Prashant Chopra   Allrounder         India                  20.0
# 7          Akeal Hosein       Bowler   West Indies                 100.0
# 8          Raghav Goyal       Bowler         India                  20.0
# 9  Yudhvir Singh Charak   Allrounder         India                  20.0
#
#    final price (in lacs) franchise    status
# 0                   20.0       KKR  RETAINED
# 1                    NaN       NaN    UNSOLD
# ...

# %%
data.describe()
# Out:
#        base price (in lacs)  final price (in lacs)
# count            151.000000             238.000000
# mean              59.205298             368.067227
# std               59.688337             449.070117
# min               20.000000              20.000000
# 25%               20.000000              21.250000
# 50%               20.000000             150.000000
# 75%               75.000000             625.000000
# max              200.000000            1850.000000

# %%
data.shape
# Out:
# (309, 7)

# %%
data.isna().sum()  #gets all the null values in the coloumns- checks for null values
# Out:
# name                       0
# player style               0
# nationality                0
# base price (in lacs)     158
# final price (in lacs)     71
# franchise                 71
# status                     0
# dtype: int64

# %%
data
# Out:
#                 name player style   nationality  base price (in lacs)
# 0       Harshit Rana       Bowler         India                   NaN  \
# 1          Ekant Sen       Batter         India                  20.0
# 2      Wayne Parnell   Allrounder  South Africa                  75.0
# 3    Shakib Al Hasan   Allrounder    Bangladesh                 150.0
# 4           Joe Root       Batter       England                 100.0
# ..               ...          ...           ...                   ...
# 304         MS Dhoni    WK-Batter         India                   NaN
# 305        Moeen Ali   Allrounder       England                   NaN
# 306  Ruturaj Gaikwad       Batter         India                   NaN
# 307     Rishabh Pant    WK-Batter         India                   NaN
# 308       Axar Patel   Allrounder         India                   NaN
#
#      final price (in lacs) franchise    status
# 0                     20.0       KKR  RETAINED
# ...

# %%
data['final price (in lacs)'].sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of 0        20.0
# 1         NaN
# 2         NaN
# 3       150.0
# 4       100.0
#         ...
# 304    1200.0
# 305     800.0
# 306     600.0
# 307    1600.0
# 308     900.0
# Name: final price (in lacs), Length: 309, dtype: float64>

# %%
data['name'].dtype
# Out:
# dtype('O')

# %%
data.loc[data.duplicated(subset=['name'])]
# Out:
# Empty DataFrame
# Columns: [name, player style, nationality, base price (in lacs), final price (in lacs), franchise, status]
# Index: []

# %%
data['final price (in lacs)'].dtype
# Out:
# dtype('float64')

# %%
data.columns
# Out:
# Index(['name', 'player style', 'nationality', 'base price (in lacs)',
#        'final price (in lacs)', 'franchise', 'status'],
#       dtype='object')

# %%
style = data['player style'].value_counts()
style
# Out:
# player style
# Bowler        111
# Allrounder    103
# Batter         55
# WK-Batter      40
# Name: count, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   name                   309 non-null    object
#  1   player style           309 non-null    object
#  2   nationality            309 non-null    object
#  3   base price (in lacs)   151 non-null    float64
#  4   final price (in lacs)  238 non-null    float64
#  5   franchise              238 non-null    object
#  6   status                 309 non-null    object
# dtypes: float64(2), object(5)
# memory usage: 17.0+ KB

# %%
from pandas.api.types import is_numeric_dtype
for col in data.columns:
    if is_numeric_dtype(data[col]):
        print('\nColumn:%s'%col)
        print('\tMean : %.2f'%data[col].mean())
        print('\tStandard deviation = %.2f' % data[col].std())
        print('\tMinimum = %.2f' % data[col].min())
        print('\tMaximum = %.2f' % data[col].max())
# Out:
# Column:base price (in lacs)
# 	Mean : 59.21
# 	Standard deviation = 59.69
# 	Minimum = 20.00
# 	Maximum = 200.00
#
# Column:final price (in lacs)
# 	Mean : 368.07
# 	Standard deviation = 449.07
# 	Minimum = 20.00
# 	Maximum = 1850.00

# %%
data.isnull().sum()
# Out:
# name                       0
# player style               0
# nationality                0
# base price (in lacs)     158
# final price (in lacs)     71
# franchise                 71
# status                     0
# dtype: int64

# %%
duplicates = data[data.duplicated()]
print('Number of duplicated items: ',len(duplicates))
# Out:
# Number of duplicated items:  0

# %%
data.dtypes
# Out:
# name                      object
# player style              object
# nationality               object
# base price (in lacs)     float64
# final price (in lacs)    float64
# franchise                 object
# status                    object
# dtype: object

# %%
data.nunique()
# Out:
# name                     309
# player style               4
# nationality               14
# base price (in lacs)       8
# final price (in lacs)     67
# franchise                 10
# status                     3
# dtype: int64

# %%
data['nationality'].value_counts()
# Out:
# nationality
# India           201
# England          24
# South Africa     19
# West Indies      14
# Australia        14
# New Zealand      11
# Sri Lanka         8
# Afghanistan       7
# Bangladesh        4
# Ireland           2
# Zimbabwe          2
# Namibia           1
# Netherlands       1
# Singapore         1
# Name: count, dtype: int64

# %% [markdown]
# VISUALIZATIONS

# %%
import matplotlib.pyplot as plt
data['nationality'].value_counts().plot(kind='bar',color='green')
plt.show()

# %%
data['player style'].value_counts().plot(kind='bar',color='pink')
plt.show()

# %%
data['player style'].value_counts().plot(kind='pie',colors=['blue','red','green','violet'])
plt.show()

# %%
data['nationality'].value_counts().plot(kind='pie')
plt.show()

# %%
data.keys()
# Out:
# Index(['name', 'player style', 'nationality', 'base price (in lacs)',
#        'final price (in lacs)', 'franchise', 'status'],
#       dtype='object')

# %%
import seaborn as sns
sns.pairplot(data,hue='nationality')
plt.show()

# %%
sns.pairplot(data,hue='player style')
plt.show()

# %%
sns.countplot(x='player style', data= data)

plt.show()

# %%
g1=data.groupby('player style')['base price (in lacs)'].mean().idxmax()
g2=data.groupby('player style')['base price (in lacs)'].mean().max()
g3=data.groupby('player style')['base price (in lacs)'].mean().idxmin()
g4=data.groupby('player style')['base price (in lacs)'].mean().min()



print(f'The playing style {g1} has the highest base price on avg of {round(g2,2)} lacs')
print(f'The playing style {g3} has the lowest base price on avg of {round(g4,2)} lacs')
# Out:
# The playing style Batter has the highest base price on avg of 75.65 lacs
# The playing style WK-Batter has the lowest base price on avg of 45.24 lacs

# %% [markdown]
# FRANCHISE ANALYSIS

# %%
grp=data.groupby('franchise')['final price (in lacs)'].sum()
grp
# Out:
# franchise
# CSK     9350.0
# DC      8685.0
# GT      9055.0
# KKR     6410.0
# LSG     9065.0
# MI      9420.0
# PBKS    8280.0
# RCB     9325.0
# RR      9165.0
# SRH     8845.0
# Name: final price (in lacs), dtype: float64

# %%
grp1=data.groupby('franchise')['final price (in lacs)'].mean().sort_values().reset_index()
grp1
# Out:
#   franchise  final price (in lacs)
# 0       KKR             337.368421
# 1       SRH             353.800000
# 2        DC             361.875000
# 3        GT             362.200000
# 4       LSG             362.600000
# 5        RR             366.600000
# 6       RCB             373.000000
# 7       CSK             374.000000
# 8      PBKS             376.363636
# 9        MI             409.565217

# %%
grp1['franchise'].values
# Out:
# array(['KKR', 'SRH', 'DC', 'GT', 'LSG', 'RR', 'RCB', 'CSK', 'PBKS', 'MI'],
#       dtype=object)

# %%
plt.bar(grp1['franchise'],grp1['final price (in lacs)'])
plt.show()

# %%
plt.pie(grp1['final price (in lacs)'],
        labels=['KKR', 'SRH', 'DC', 'GT', 'LSG', 'RR', 'RCB', 'CSK', 'PBKS', 'MI'],
        autopct='%1.3f',
        explode=[0,0,0,0,0,0,0,0,0,.3],
        startangle=30,
        shadow=True)
plt.title('final price of each franchise (in lacs)')
plt.show()

# %%
# ASSUMING DATA IS YOUR DATAFRAME COTAINING DATA ABOUT STATUS AND FRANCHISE
# GROUPING BT 'STATUS ' AND 'FRANCHISE ', AND COUNTING OCCURRENCES
st = data.groupby('status')['franchise'].value_counts()


# SELECTING COUNTS FOR RETAINED STATUS
st1=st.loc['RETAINED']

# FINDING THE MAX COUNT OF FRANCHISE FOR 'RETAINED' STATUS
max_count = st1.max()

print("Maximum count of franchises for 'RETAINED' status:" ,max_count)
# Out:
# Maximum count of franchises for 'RETAINED' status: 19

# %% [markdown]
# PLAYER PRICE ANALYSIS

# %%
nation = data.groupby('nationality')[['base price (in lacs)','final price (in lacs)']].mean().reset_index()
nation
# Out:
#      nationality  base price (in lacs)  final price (in lacs)
# 0    Afghanistan             67.500000             407.500000
# 1      Australia            136.428571             591.818182
# 2     Bangladesh             83.333333             133.333333
# 3        England            136.470588             745.666667
# 4          India             25.444444             323.456790
# 5        Ireland             50.000000             440.000000
# 6        Namibia            100.000000             100.000000
# 7    Netherlands             20.000000                    NaN
# 8    New Zealand            160.000000             221.250000
# 9      Singapore                   NaN             825.000000
# 10  South Africa             91.875000             360.333333
# 11     Sri Lanka             50.000000             303.750000
# 12   West Indies            114.285714             472.500000
# 13      Zimbabwe             50.000000              50.000000

# %%
data[data['nationality']=='Australia']
# Out:
#                 name player style nationality  base price (in lacs)
# 23        Adam Zampa       Bowler   Australia                 150.0  \
# 85    Riley Meredith       Bowler   Australia                 150.0
# 89       Daniel Sams   Allrounder   Australia                  75.0
# 93       Travis Head   Allrounder   Australia                 200.0
# 106     Lance Morris       Bowler   Australia                  30.0
# 140  Jhye Richardson       Bowler   Australia                 150.0
# 148    Cameron Green   Allrounder   Australia                 200.0
# 188     Nathan Ellis       Bowler   Australia                   NaN
# 218   Josh Hazlewood       Bowler   Australia                   NaN
# 225     Matthew Wade    WK-Batter   Australia                   NaN
# 243   Mitchell Marsh   Allrounder   Australia                   NaN
# 269     David Warner       Batter   Australia                   NaN
# 281    Glenn Maxwell   Allrounder   Australia                   NaN
# ...

# %%
data[data['status']=='UNSOLD']['base price (in lacs)'].mean()
# Out:
# 55.63380281690141

# %%
# x_ = nation['nationality']
# y_ = nation['base price (in lacs)']
# y1 = nation['final price (in lacs)']

nation.plot(kind='bar', x='nationality')
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# STATUS ANALYSIS

# %%
sta=data['status'].value_counts().reset_index()
sta
# Out:
#      status  count
# 0  RETAINED    158
# 1      SOLD     80
# 2    UNSOLD     71

# %%
df = data.groupby('status')[['base price (in lacs)','final price (in lacs)']].mean().reset_index()
df
# Out:
#      status  base price (in lacs)  final price (in lacs)
# 0  RETAINED                   NaN             448.734177
# 1      SOLD             62.375000             208.750000
# 2    UNSOLD             55.633803                    NaN

# %%
df.plot(kind='bar', x='status')
plt.xticks(rotation=30)
plt.ylabel('Price in lakhs')
plt.title('Data of Players Price',fontweight='bold')
plt.show()
